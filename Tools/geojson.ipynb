# %%
import geopandas
from sqlalchemy import create_engine

# %%
# gdf = geopandas.read_file("../data/highway_michelstadt.geojson")
gdf = geopandas.read_file("../data/obstruction_michelstadt.geojson")
gdf.head()
# Out:
#     landuse military                                    name  \
# 0  military     None     Ehmaliger Munitionssprengplatz Gönz
# 1      None     None  Steinbacher Teich und Fürstenauer Park
# 2      None     None     Bruch von Bad König und Etzen-Gesäß
# 3      None     None  Schmerbachtal von Fürth und Hammelbach
# 4      None     None           Flugsportclub Mümlingtal e.V.
#
#                                                 note operator operator:type  \
# 0                                               None     None          None
# 1  Grenzen NSG nach präziser NATUREG-Shape-Datei ...     None          None
# 2  Grenzen NSG nach präziser NATUREG-Shape-Datei ...     None          None
# 3  Grenzen NSG nach präziser NATUREG-Shape-Datei ...     None          None
# 4                                               None     None          None
#
#   protect_class   protection_title ref:DE-BY ref:DE-HE  ... building   ele  \
# ...

# %%
sub = gdf[["name", "geometry"]]
sub.head()
# Out:
#                                      name  \
# 0     Ehmaliger Munitionssprengplatz Gönz
# 1  Steinbacher Teich und Fürstenauer Park
# 2     Bruch von Bad König und Etzen-Gesäß
# 3  Schmerbachtal von Fürth und Hammelbach
# 4           Flugsportclub Mümlingtal e.V.
#
#                                             geometry
# 0  POLYGON ((9.09097 49.68845, 9.09041 49.68985, ...
# 1  MULTIPOLYGON (((8.99896 49.68572, 8.99899 49.6...
# 2  MULTIPOLYGON (((8.99778 49.75715, 8.99648 49.7...
# 3  MULTIPOLYGON (((8.86077 49.64643, 8.86083 49.6...
# 4  POLYGON ((9.08259 49.72270, 9.08265 49.72245, ...

# %%
engine = create_engine("postgresql://postgres:password@localhost:5432/osm")
sub.to_postgis("obstruction_michelstadt", engine)

# %%
sub.plot()
# Out:
# <AxesSubplot: >
